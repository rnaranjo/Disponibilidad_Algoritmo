# %%
import pandas as pd
from math import ceil
from datetime import timedelta
from model import Shifts

# %% [markdown]
# ## Load Data from .csv

# %%
shifts = pd.read_csv('shifts.csv', parse_dates=['Inicio_Turno','Fin_Turno'], date_parser=lambda x: pd.to_datetime(x, format="%H:%M"))
periodos = 24
tiempo = [(timedelta(hours=0, minutes=15*i * 96/periodos)) for i in range(int(periodos))]
shifts['in'] = shifts['Inicio_Turno'].apply(lambda x: tiempo.index(timedelta(hours=x.hour, minutes=x.minute)))
shifts['out'] = shifts['Fin_Turno'].apply(lambda x: len(tiempo) if x.hour==0 and x.minute==0 else tiempo.index(timedelta(hours=x.hour, minutes=x.minute)))
shifts['Lenght'] = shifts['out'] -shifts['in']

forecast = pd.read_csv('forecast.csv', index_col=0,parse_dates=["fecha"])
dates = forecast['fecha'].dt.date.unique()
forecast['demanda'] = forecast['demanda']/2
# Out:
# /var/folders/k4/9s2d7pcj1j15dhx3p_kwf5mm0000gn/T/ipykernel_11963/1014215502.py:1: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   shifts = pd.read_csv('shifts.csv', parse_dates=['Inicio_Turno','Fin_Turno'], date_parser=lambda x: pd.to_datetime(x, format="%H:%M"))

# %% [markdown]
# ## Optimiza Demanda en Base a Turnos con modelo MIP

# %%
def create_shift_pattern(shifts, forecast):
    A = [[0 for _ in range(len(shifts))] for __ in range(len(forecast))]
    for j, shift in shifts.iterrows():
        for i, demand in forecast.iterrows():
            if shift['in'] <= i < shift['out']:
                A[i][j] = 1
    return A

shift_pattern = {}
for d, date in enumerate(dates):
    daily_forecats = forecast[(forecast['fecha'].dt.day==date.day) & (forecast['fecha'].dt.month==date.month)].sort_values(by='fecha').reset_index(drop=True)
    shift_pattern[d] = create_shift_pattern(shifts, daily_forecats)

result_shift = {}
for i, date in enumerate(dates):

    daily_forecats = forecast[(forecast['fecha'].dt.day==date.day) & (forecast['fecha'].dt.month==date.month)].sort_values(by='fecha').reset_index(drop=True)
    sets = {}
    sets['Forecast'] = daily_forecats['demanda'].to_dict()
    sets['Shifts'] = {s:s for s in shifts.index.to_list()}

    parameters = {}
    parameters['Cost'] = shifts['Lenght'].to_dict()
    parameters['A'] = shift_pattern[i]

    modelo = Shifts()
    modelo.sets(sets)
    modelo.parameters(parameters)
    modelo.variables()
    modelo.constrains()
    modelo.objetive()
    daily_result = modelo.execute()
    result_shift[i] = daily_result
# Out:
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0024I Matrix will be packed to eliminate 160 small elements
# Coin0506I Presolve 8 (-16) rows, 9 (0) columns and 27 (-29) elements
# Clp1000I sum of infeasibilities 6.82543e-08 - average 8.53179e-09, 4 fixed columns
# Coin0506I Presolve 6 (-2) rows, 5 (-4) columns and 17 (-10) elements
# Clp0006I 0  Obj 41.999997 Dual inf 1200 (3)
# Clp0029I End of values pass after 3 iterations
# Clp0000I Optimal - objective value 42
# Clp0000I Optimal - objective value 42
# Coin0511I After Postsolve, objective 42, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 42
# Clp0000I Optimal - objective value 42
# Clp0000I Optimal - objective value 42
# Clp0000I Optimal - objective value 42
# Coin0511I After Postsolve, objective 42, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 42 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
#
# Starting MIP optimization
# maxSavedSolutions was changed from 1 to 10
# Continuous objective value is 42 - 4.7e-05 seconds
# Cgl0003I 0 fixed, 9 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 8 rows, 9 columns (9 integer (0 of which binary)) and 27 elements
# Coin3009W Conflict graph built in 0.001 seconds, density: 0.000%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0012I Integer solution of 56 found by greedy cover after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0012I Integer solution of 52 found by DiveCoefficient after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0038I Full problem 8 rows 9 columns, reduced to 0 rows 0 columns
# Cbc0012I Integer solution of 44 found by RINS after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0001I Search completed - best objective 44, took 0 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 42 to 42
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# OddWheel was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
#
# Result - Optimal solution found
# Objective value:                44
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.001639
# Time (Wallclock seconds):       0.0103631
# Total time (CPU seconds):       0.001714   (Wallclock seconds):       0.012995
# Status: OptimizationStatus.OPTIMAL
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0024I Matrix will be packed to eliminate 160 small elements
# Coin0506I Presolve 9 (-15) rows, 9 (0) columns and 30 (-26) elements
# Clp1000I sum of infeasibilities 0 - average 0, 1 fixed columns
# Coin0506I Presolve 9 (0) rows, 8 (-1) columns and 27 (-3) elements
# Clp0006I 0  Obj 44.000127 Dual inf 4800 (8)
# Clp0029I End of values pass after 8 iterations
# Clp0000I Optimal - objective value 44
# Clp0000I Optimal - objective value 44
# Coin0511I After Postsolve, objective 44, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 44
# Clp0000I Optimal - objective value 44
# Clp0000I Optimal - objective value 44
# Clp0000I Optimal - objective value 44
# Coin0511I After Postsolve, objective 44, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 44 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
#
# Starting MIP optimization
# maxSavedSolutions was changed from 1 to 10
# Continuous objective value is 44 - 2.3e-05 seconds
# Cgl0003I 0 fixed, 9 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0004I processed model has 8 rows, 9 columns (9 integer (0 of which binary)) and 26 elements
# Coin3009W Conflict graph built in 0.000 seconds, density: 0.000%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0012I Integer solution of 52 found by greedy cover after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0012I Integer solution of 48 found by DiveCoefficient after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective 48, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 46 to 46
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# OddWheel was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
#
# Result - Optimal solution found
# Objective value:                48
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.001183
# Time (Wallclock seconds):       0.00128317
# Total time (CPU seconds):       0.001226   (Wallclock seconds):       0.0013411
# Status: OptimizationStatus.OPTIMAL
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0024I Matrix will be packed to eliminate 160 small elements
# Coin0506I Presolve 9 (-15) rows, 9 (0) columns and 30 (-26) elements
# Clp1000I sum of infeasibilities 3.19389e-12 - average 3.54877e-13, 1 fixed columns
# Coin0506I Presolve 9 (0) rows, 8 (-1) columns and 27 (-3) elements
# Clp0006I 0  Obj 46.000049 Dual inf 4800 (8)
# Clp0029I End of values pass after 8 iterations
# Clp0000I Optimal - objective value 46
# Clp0000I Optimal - objective value 46
# Coin0511I After Postsolve, objective 46, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 46
# Clp0000I Optimal - objective value 46
# Clp0000I Optimal - objective value 46
# Clp0000I Optimal - objective value 46
# Coin0511I After Postsolve, objective 46, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 46 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
#
# Starting MIP optimization
# maxSavedSolutions was changed from 1 to 10
# Continuous objective value is 46 - 2.1e-05 seconds
# Cgl0003I 0 fixed, 9 tightened bounds, 2 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 2 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 2 strengthened rows, 0 substitutions
# Cgl0004I processed model has 9 rows, 9 columns (9 integer (0 of which binary)) and 30 elements
# Coin3009W Conflict graph built in 0.000 seconds, density: 0.000%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0012I Integer solution of 64 found by greedy cover after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0012I Integer solution of 52 found by DiveCoefficient after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0031I 2 added rows had average density of 3
# Cbc0013I At root node, 5 cuts changed objective from 46 to 52 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 1 column cuts (1 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 2 row cuts average 2.5 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (OddWheel) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (MixedIntegerRounding2) - 1 row cuts average 4.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 6 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (TwoMirCuts) - 2 row cuts average 2.5 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 52, took 1 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 46 to 52
# Probing was tried 1 times and created 1 cuts of which 0 were active after adding rounds of cuts (2e-05 seconds)
# Gomory was tried 1 times and created 2 cuts of which 0 were active after adding rounds of cuts (1.6e-05 seconds)
# Knapsack was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (7e-06 seconds)
# Clique was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (2e-06 seconds)
# OddWheel was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (2e-06 seconds)
# MixedIntegerRounding2 was tried 1 times and created 1 cuts of which 0 were active after adding rounds of cuts (1.3e-05 seconds)
# FlowCover was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (1e-05 seconds)
# TwoMirCuts was tried 1 times and created 2 cuts of which 0 were active after adding rounds of cuts (3.2e-05 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (9e-06 seconds)
#
# Result - Optimal solution found
# Objective value:                52
# Enumerated nodes:               0
# Total iterations:               1
# Time (CPU seconds):             0.001549
# Time (Wallclock seconds):       0.0019412
# Total time (CPU seconds):       0.001586   (Wallclock seconds):       0.00199103
# Status: OptimizationStatus.OPTIMAL
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0024I Matrix will be packed to eliminate 160 small elements
# Coin0506I Presolve 9 (-15) rows, 9 (0) columns and 30 (-26) elements
# Clp1000I sum of infeasibilities 6.01552e-08 - average 6.68391e-09, 1 fixed columns
# Coin0506I Presolve 9 (0) rows, 8 (-1) columns and 27 (-3) elements
# Clp0006I 0  Obj 42.000175 Dual inf 4800 (8)
# Clp0029I End of values pass after 8 iterations
# Clp0000I Optimal - objective value 42
# Clp0000I Optimal - objective value 42
# Coin0511I After Postsolve, objective 42, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 42
# Clp0000I Optimal - objective value 42
# Clp0000I Optimal - objective value 42
# Clp0000I Optimal - objective value 42
# Coin0511I After Postsolve, objective 42, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 42 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
#
# Starting MIP optimization
# maxSavedSolutions was changed from 1 to 10
# Continuous objective value is 42 - 2.1e-05 seconds
# Cgl0003I 0 fixed, 9 tightened bounds, 2 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 2 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0004I processed model has 9 rows, 9 columns (9 integer (0 of which binary)) and 30 elements
# Coin3009W Conflict graph built in 0.000 seconds, density: 0.000%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0012I Integer solution of 48 found by greedy cover after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0038I Full problem 9 rows 9 columns, reduced to 0 rows 0 columns
# Cbc0012I Integer solution of 44 found by RINS after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective 44, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 44 to 44
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# OddWheel was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
#
# Result - Optimal solution found
# Objective value:                44
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.001542
# Time (Wallclock seconds):       0.00163698
# Total time (CPU seconds):       0.001592   (Wallclock seconds):       0.00170398
# Status: OptimizationStatus.OPTIMAL
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0024I Matrix will be packed to eliminate 160 small elements
# Coin0506I Presolve 9 (-15) rows, 9 (0) columns and 30 (-26) elements
# Clp1000I sum of infeasibilities 2.34982e-08 - average 2.61091e-09, 1 fixed columns
# Coin0506I Presolve 9 (0) rows, 8 (-1) columns and 27 (-3) elements
# Clp0006I 0  Obj 48.000053 Dual inf 4800 (8)
# Clp0029I End of values pass after 8 iterations
# Clp0000I Optimal - objective value 48
# Clp0000I Optimal - objective value 48
# Coin0511I After Postsolve, objective 48, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 48
# Clp0000I Optimal - objective value 48
# Clp0000I Optimal - objective value 48
# Clp0000I Optimal - objective value 48
# Coin0511I After Postsolve, objective 48, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 48 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
#
# Starting MIP optimization
# maxSavedSolutions was changed from 1 to 10
# Continuous objective value is 48 - 3.4e-05 seconds
# Cgl0003I 0 fixed, 9 tightened bounds, 2 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 2 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0004I processed model has 9 rows, 9 columns (9 integer (0 of which binary)) and 30 elements
# Coin3009W Conflict graph built in 0.000 seconds, density: 0.000%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0012I Integer solution of 68 found by greedy cover after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0012I Integer solution of 56 found by DiveCoefficient after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0031I 2 added rows had average density of 3
# Cbc0013I At root node, 5 cuts changed objective from 50 to 56 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 1 column cuts (1 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 2 row cuts average 2.5 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (OddWheel) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (MixedIntegerRounding2) - 1 row cuts average 4.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 6 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (TwoMirCuts) - 2 row cuts average 2.5 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 56, took 1 iterations and 0 nodes (0.03 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 50 to 56
# Probing was tried 1 times and created 1 cuts of which 0 were active after adding rounds of cuts (1.7e-05 seconds)
# Gomory was tried 1 times and created 2 cuts of which 0 were active after adding rounds of cuts (1.7e-05 seconds)
# Knapsack was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (7e-06 seconds)
# Clique was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (2e-06 seconds)
# OddWheel was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (2e-06 seconds)
# MixedIntegerRounding2 was tried 1 times and created 1 cuts of which 0 were active after adding rounds of cuts (1.3e-05 seconds)
# FlowCover was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (1.1e-05 seconds)
# TwoMirCuts was tried 1 times and created 2 cuts of which 0 were active after adding rounds of cuts (3.1e-05 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.00132 seconds)
#
# Result - Optimal solution found
# Objective value:                56
# Enumerated nodes:               0
# Total iterations:               1
# Time (CPU seconds):             0.003199
# Time (Wallclock seconds):       0.026933
# Total time (CPU seconds):       0.003264   (Wallclock seconds):       0.0270369
# Status: OptimizationStatus.OPTIMAL
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0024I Matrix will be packed to eliminate 160 small elements
# Coin0506I Presolve 9 (-15) rows, 9 (0) columns and 30 (-26) elements
# Clp1000I sum of infeasibilities 7.02516e-09 - average 7.80573e-10, 1 fixed columns
# Coin0506I Presolve 9 (0) rows, 8 (-1) columns and 27 (-3) elements
# Clp0006I 0  Obj 42.000065 Dual inf 5200 (8)
# Clp0029I End of values pass after 8 iterations
# Clp0000I Optimal - objective value 42
# Clp0000I Optimal - objective value 42
# Coin0511I After Postsolve, objective 42, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 42
# Clp0000I Optimal - objective value 42
# Clp0000I Optimal - objective value 42
# Clp0000I Optimal - objective value 42
# Coin0511I After Postsolve, objective 42, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 42 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
#
# Starting MIP optimization
# maxSavedSolutions was changed from 1 to 10
# Continuous objective value is 42 - 3.6e-05 seconds
# Cgl0003I 0 fixed, 9 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 9 rows, 9 columns (9 integer (0 of which binary)) and 30 elements
# Coin3009W Conflict graph built in 0.000 seconds, density: 0.000%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0012I Integer solution of 56 found by greedy cover after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0012I Integer solution of 52 found by DiveCoefficient after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0038I Full problem 9 rows 9 columns, reduced to 1 rows 2 columns
# Cbc0012I Integer solution of 44 found by RINS after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective 44, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 42 to 42
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# OddWheel was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
#
# Result - Optimal solution found
# Objective value:                44
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.001828
# Time (Wallclock seconds):       0.00407887
# Total time (CPU seconds):       0.001906   (Wallclock seconds):       0.00416803
# Status: OptimizationStatus.OPTIMAL
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0024I Matrix will be packed to eliminate 160 small elements
# Coin0506I Presolve 9 (-15) rows, 9 (0) columns and 30 (-26) elements
# Clp1000I sum of infeasibilities 2.50043e-08 - average 2.77825e-09, 0 fixed columns
# Coin0506I Presolve 9 (0) rows, 9 (0) columns and 30 (0) elements
# Clp0006I 0  Obj 40.00019 Dual inf 5600 (9)
# Clp0029I End of values pass after 9 iterations
# Clp0000I Optimal - objective value 40
# Clp0000I Optimal - objective value 40
# Clp0000I Optimal - objective value 40
# Coin0511I After Postsolve, objective 40, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 40 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
#
# Starting MIP optimization
# maxSavedSolutions was changed from 1 to 10
# Continuous objective value is 40 - 2.5e-05 seconds
# Cgl0003I 0 fixed, 9 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 9 rows, 9 columns (9 integer (0 of which binary)) and 30 elements
# Coin3009W Conflict graph built in 0.000 seconds, density: 0.000%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0012I Integer solution of 56 found by greedy cover after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0012I Integer solution of 48 found by DiveCoefficient after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0038I Full problem 9 rows 9 columns, reduced to 0 rows 0 columns
# Cbc0012I Integer solution of 44 found by RINS after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0006I The LP relaxation is infeasible or too expensive
# Cbc0013I At root node, 0 cuts changed objective from 40 to 44 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 1 column cuts (1 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (OddWheel) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 8 (ZeroHalf) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 44, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 40 to 44
# Probing was tried 1 times and created 1 cuts of which 0 were active after adding rounds of cuts (1.6e-05 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# OddWheel was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
#
# Result - Optimal solution found
# Objective value:                44
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.001267
# Time (Wallclock seconds):       0.00150609
# Total time (CPU seconds):       0.00131   (Wallclock seconds):       0.00156999
# Status: OptimizationStatus.OPTIMAL
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0024I Matrix will be packed to eliminate 160 small elements
# Coin0506I Presolve 9 (-15) rows, 9 (0) columns and 30 (-26) elements
# Clp1000I sum of infeasibilities 4.19052e-08 - average 4.65613e-09, 1 fixed columns
# Coin0506I Presolve 9 (0) rows, 8 (-1) columns and 27 (-3) elements
# Clp0006I 0  Obj 44.000086 Dual inf 4800 (8)
# Clp0029I End of values pass after 8 iterations
# Clp0000I Optimal - objective value 44
# Clp0000I Optimal - objective value 44
# Coin0511I After Postsolve, objective 44, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 44
# Clp0000I Optimal - objective value 44
# Clp0000I Optimal - objective value 44
# Clp0000I Optimal - objective value 44
# Coin0511I After Postsolve, objective 44, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 44 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
#
# Starting MIP optimization
# maxSavedSolutions was changed from 1 to 10
# Continuous objective value is 44 - 2.1e-05 seconds
# Cgl0003I 0 fixed, 9 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0004I processed model has 9 rows, 9 columns (9 integer (0 of which binary)) and 30 elements
# Coin3009W Conflict graph built in 0.000 seconds, density: 0.000%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0012I Integer solution of 60 found by greedy cover after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0012I Integer solution of 52 found by DiveCoefficient after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0038I Full problem 9 rows 9 columns, reduced to 0 rows 0 columns
# Cbc0012I Integer solution of 48 found by RINS after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0006I The LP relaxation is infeasible or too expensive
# Cbc0013I At root node, 0 cuts changed objective from 44 to 46 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 1 column cuts (1 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (OddWheel) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 8 (ZeroHalf) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 48, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 44 to 46
# Probing was tried 1 times and created 1 cuts of which 0 were active after adding rounds of cuts (1.3e-05 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# OddWheel was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
#
# Result - Optimal solution found
# Objective value:                48
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.001444
# Time (Wallclock seconds):       0.00147414
# Total time (CPU seconds):       0.001478   (Wallclock seconds):       0.00152612
# Status: OptimizationStatus.OPTIMAL
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0024I Matrix will be packed to eliminate 160 small elements
# Coin0506I Presolve 8 (-16) rows, 9 (0) columns and 26 (-30) elements
# Clp1000I sum of infeasibilities 3.80584e-13 - average 4.75731e-14, 2 fixed columns
# Coin0506I Presolve 6 (-2) rows, 7 (-2) columns and 17 (-9) elements
# Clp0006I 0  Obj 44.000048 Dual inf 3200 (6)
# Clp0029I End of values pass after 6 iterations
# Clp0000I Optimal - objective value 44
# Clp0000I Optimal - objective value 44
# Coin0511I After Postsolve, objective 44, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 44
# Clp0000I Optimal - objective value 44
# Clp0000I Optimal - objective value 44
# Clp0000I Optimal - objective value 44
# Coin0511I After Postsolve, objective 44, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 44 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
#
# Starting MIP optimization
# maxSavedSolutions was changed from 1 to 10
# Continuous objective value is 44 - 2.2e-05 seconds
# Cgl0003I 0 fixed, 9 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 8 rows, 9 columns (9 integer (0 of which binary)) and 26 elements
# Coin3009W Conflict graph built in 0.000 seconds, density: 0.000%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0012I Integer solution of 56 found by greedy cover after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0012I Integer solution of 48 found by DiveCoefficient after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0006I The LP relaxation is infeasible or too expensive
# Cbc0013I At root node, 0 cuts changed objective from 44 to 46 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 1 column cuts (1 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (OddWheel) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 8 (ZeroHalf) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 48, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 44 to 46
# Probing was tried 1 times and created 1 cuts of which 0 were active after adding rounds of cuts (1.2e-05 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# OddWheel was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
#
# Result - Optimal solution found
# Objective value:                48
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.001127
# Time (Wallclock seconds):       0.00117302
# Total time (CPU seconds):       0.001158   (Wallclock seconds):       0.00122094
# Status: OptimizationStatus.OPTIMAL
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0024I Matrix will be packed to eliminate 160 small elements
# Coin0506I Presolve 8 (-16) rows, 9 (0) columns and 26 (-30) elements
# Clp1000I sum of infeasibilities 5.48552e-08 - average 6.8569e-09, 1 fixed columns
# Coin0506I Presolve 8 (0) rows, 8 (-1) columns and 24 (-2) elements
# Clp0006I 0  Obj 44.000184 Dual inf 4800 (8)
# Clp0029I End of values pass after 8 iterations
# Clp0014I Perturbing problem by 0.001% of 1.8750125 - largest nonzero change 2.7226232e-05 ( 0.00090754108%) - largest zero change 1.7713121e-05
# Clp0000I Optimal - objective value 44
# Clp0000I Optimal - objective value 44
# Coin0511I After Postsolve, objective 44, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 44
# Clp0000I Optimal - objective value 44
# Clp0000I Optimal - objective value 44
# Clp0000I Optimal - objective value 44
# Coin0511I After Postsolve, objective 44, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 44 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
#
# Starting MIP optimization
# maxSavedSolutions was changed from 1 to 10
# Continuous objective value is 44 - 2.9e-05 seconds
# Cgl0003I 0 fixed, 9 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 8 rows, 9 columns (9 integer (0 of which binary)) and 26 elements
# Coin3009W Conflict graph built in 0.000 seconds, density: 0.000%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0012I Integer solution of 44 found by greedy cover after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective 44, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 44 to 44
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# OddWheel was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
#
# Result - Optimal solution found
# Objective value:                44
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.000945
# Time (Wallclock seconds):       0.00107503
# Total time (CPU seconds):       0.000991   (Wallclock seconds):       0.00113702
# Status: OptimizationStatus.OPTIMAL
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0024I Matrix will be packed to eliminate 160 small elements
# Coin0506I Presolve 6 (-18) rows, 6 (-3) columns and 17 (-39) elements
# Clp1000I sum of infeasibilities 0 - average 0, 1 fixed columns
# Coin0506I Presolve 5 (-1) rows, 5 (-1) columns and 11 (-6) elements
# Clp0006I 0  Obj 50.000094 Dual inf 2800 (5)
# Clp0029I End of values pass after 5 iterations
# Clp0000I Optimal - objective value 50
# Clp0000I Optimal - objective value 50
# Coin0511I After Postsolve, objective 50, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 50
# Clp0000I Optimal - objective value 50
# Clp0000I Optimal - objective value 50
# Clp0000I Optimal - objective value 50
# Coin0511I After Postsolve, objective 50, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 50 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
#
# Starting MIP optimization
# maxSavedSolutions was changed from 1 to 10
# Continuous objective value is 50 - 4.2e-05 seconds
# Cgl0003I 0 fixed, 6 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 6 rows, 6 columns (6 integer (0 of which binary)) and 17 elements
# Coin3009W Conflict graph built in 0.000 seconds, density: 0.000%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0012I Integer solution of 56 found by greedy cover after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0012I Integer solution of 52 found by DiveCoefficient after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective 52, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 50 to 50
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# OddWheel was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
#
# Result - Optimal solution found
# Objective value:                52
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.000955
# Time (Wallclock seconds):       0.00130701
# Total time (CPU seconds):       0.001017   (Wallclock seconds):       0.00138688
# Status: OptimizationStatus.OPTIMAL
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0024I Matrix will be packed to eliminate 160 small elements
# Coin0506I Presolve 6 (-18) rows, 6 (-3) columns and 17 (-39) elements
# Clp1000I sum of infeasibilities 3.98416e-10 - average 6.64027e-11, 0 fixed columns
# Coin0506I Presolve 6 (0) rows, 6 (0) columns and 17 (0) elements
# Clp0006I 0  Obj 54.000037 Dual inf 3600 (6)
# Clp0029I End of values pass after 6 iterations
# Clp0000I Optimal - objective value 54
# Clp0000I Optimal - objective value 54
# Clp0000I Optimal - objective value 54
# Coin0511I After Postsolve, objective 54, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 54 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
#
# Starting MIP optimization
# maxSavedSolutions was changed from 1 to 10
# Continuous objective value is 54 - 2.3e-05 seconds
# Cgl0003I 0 fixed, 6 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 6 rows, 6 columns (6 integer (0 of which binary)) and 17 elements
# Coin3009W Conflict graph built in 0.000 seconds, density: 0.000%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0012I Integer solution of 60 found by greedy cover after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0012I Integer solution of 56 found by DiveCoefficient after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective 56, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 54 to 54
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# OddWheel was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
#
# Result - Optimal solution found
# Objective value:                56
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.000871
# Time (Wallclock seconds):       0.00095892
# Total time (CPU seconds):       0.000915   (Wallclock seconds):       0.00101614
# Status: OptimizationStatus.OPTIMAL
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0024I Matrix will be packed to eliminate 160 small elements
# Coin0506I Presolve 9 (-15) rows, 9 (0) columns and 30 (-26) elements
# Clp1000I sum of infeasibilities 3.4095e-08 - average 3.78833e-09, 1 fixed columns
# Coin0506I Presolve 7 (-2) rows, 8 (-1) columns and 25 (-5) elements
# Clp0006I 0  Obj 44.000081 Dual inf 4000 (7)
# Clp0029I End of values pass after 7 iterations
# Clp0000I Optimal - objective value 44
# Clp0000I Optimal - objective value 44
# Coin0511I After Postsolve, objective 44, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 44
# Clp0000I Optimal - objective value 44
# Clp0000I Optimal - objective value 44
# Clp0000I Optimal - objective value 44
# Coin0511I After Postsolve, objective 44, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 44 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
#
# Starting MIP optimization
# maxSavedSolutions was changed from 1 to 10
# Continuous objective value is 44 - 2.1e-05 seconds
# Cgl0003I 0 fixed, 9 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 9 rows, 9 columns (9 integer (0 of which binary)) and 30 elements
# Coin3009W Conflict graph built in 0.000 seconds, density: 0.000%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0012I Integer solution of 56 found by greedy cover after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0012I Integer solution of 52 found by DiveCoefficient after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0038I Full problem 9 rows 9 columns, reduced to 0 rows 0 columns
# Cbc0012I Integer solution of 48 found by RINS after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0006I The LP relaxation is infeasible or too expensive
# Cbc0013I At root node, 0 cuts changed objective from 44 to 46 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 1 column cuts (1 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (OddWheel) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 8 (ZeroHalf) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 48, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 44 to 46
# Probing was tried 1 times and created 1 cuts of which 0 were active after adding rounds of cuts (1.5e-05 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# OddWheel was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# ...
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
#
# Result - Optimal solution found
# Objective value:                56
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.001071
# Time (Wallclock seconds):       0.00125194
# Total time (CPU seconds):       0.001111   (Wallclock seconds):       0.00130486
# Status: OptimizationStatus.OPTIMAL
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0024I Matrix will be packed to eliminate 160 small elements
# Coin0506I Presolve 6 (-18) rows, 6 (-3) columns and 17 (-39) elements
# Clp1000I sum of infeasibilities 1.55431e-14 - average 2.59052e-15, 1 fixed columns
# Coin0506I Presolve 5 (-1) rows, 5 (-1) columns and 11 (-6) elements
# Clp0006I 0  Obj 56.000024 Dual inf 2800 (5)
# Clp0029I End of values pass after 5 iterations
# Clp0000I Optimal - objective value 56
# Clp0000I Optimal - objective value 56
# Coin0511I After Postsolve, objective 56, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 56
# Clp0000I Optimal - objective value 56
# Clp0000I Optimal - objective value 56
# Clp0000I Optimal - objective value 56
# Coin0511I After Postsolve, objective 56, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 56 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
#
# Starting MIP optimization
# maxSavedSolutions was changed from 1 to 10
# Continuous objective value is 56 - 2.6e-05 seconds
# Cgl0003I 0 fixed, 6 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 6 rows, 6 columns (6 integer (0 of which binary)) and 17 elements
# Coin3009W Conflict graph built in 0.000 seconds, density: 0.000%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0012I Integer solution of 72 found by greedy cover after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0012I Integer solution of 64 found by DiveCoefficient after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0038I Full problem 6 rows 6 columns, reduced to 0 rows 0 columns
# Cbc0012I Integer solution of 60 found by RINS after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0006I The LP relaxation is infeasible or too expensive
# Cbc0013I At root node, 0 cuts changed objective from 56 to 58 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 1 column cuts (1 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (OddWheel) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 8 (ZeroHalf) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 60, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 56 to 58
# Probing was tried 1 times and created 1 cuts of which 0 were active after adding rounds of cuts (1.6e-05 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# OddWheel was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
#
# Result - Optimal solution found
# Objective value:                60
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.001171
# Time (Wallclock seconds):       0.0012331
# Total time (CPU seconds):       0.001227   (Wallclock seconds):       0.00130486
# Status: OptimizationStatus.OPTIMAL
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0024I Matrix will be packed to eliminate 160 small elements
# Coin0506I Presolve 6 (-18) rows, 6 (-3) columns and 17 (-39) elements
# Clp1000I sum of infeasibilities 2.53131e-14 - average 4.21885e-15, 2 fixed columns
# Coin0506I Presolve 1 (-5) rows, 2 (-4) columns and 2 (-15) elements
# Clp0006I 0  Obj 60 Dual inf 1600 (2)
# Clp0029I End of values pass after 2 iterations
# Clp0000I Optimal - objective value 60
# Clp0000I Optimal - objective value 60
# Coin0511I After Postsolve, objective 60, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 60
# Clp0000I Optimal - objective value 60
# Clp0000I Optimal - objective value 60
# Clp0000I Optimal - objective value 60
# Coin0511I After Postsolve, objective 60, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 60 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
#
# Starting MIP optimization
# maxSavedSolutions was changed from 1 to 10
# Continuous objective value is 60 - 2.8e-05 seconds
# Cgl0003I 0 fixed, 6 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 6 rows, 6 columns (6 integer (0 of which binary)) and 17 elements
# Coin3009W Conflict graph built in 0.000 seconds, density: 0.000%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0012I Integer solution of 68 found by greedy cover after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0012I Integer solution of 60 found by DiveCoefficient after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective 60, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 60 to 60
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# OddWheel was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
#
# Result - Optimal solution found
# Objective value:                60
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.000849
# Time (Wallclock seconds):       0.000907898
# Total time (CPU seconds):       0.000902   (Wallclock seconds):       0.000976086
# Status: OptimizationStatus.OPTIMAL
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0024I Matrix will be packed to eliminate 160 small elements
# Coin0506I Presolve 9 (-15) rows, 9 (0) columns and 30 (-26) elements
# Clp1000I sum of infeasibilities 2.46958e-12 - average 2.74398e-13, 1 fixed columns
# Coin0506I Presolve 6 (-3) rows, 8 (-1) columns and 20 (-10) elements
# Clp0006I 0  Obj 44 Dual inf 4800 (8)
# Clp0029I End of values pass after 8 iterations
# Clp0000I Optimal - objective value 44
# Clp0000I Optimal - objective value 44
# Coin0511I After Postsolve, objective 44, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 44
# Clp0000I Optimal - objective value 44
# Clp0000I Optimal - objective value 44
# Clp0000I Optimal - objective value 44
# Coin0511I After Postsolve, objective 44, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 44 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
#
# Starting MIP optimization
# maxSavedSolutions was changed from 1 to 10
# Continuous objective value is 44 - 3.2e-05 seconds
# Cgl0003I 0 fixed, 9 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 9 rows, 9 columns (9 integer (0 of which binary)) and 30 elements
# Coin3009W Conflict graph built in 0.000 seconds, density: 0.000%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0012I Integer solution of 56 found by greedy cover after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0012I Integer solution of 44 found by DiveCoefficient after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective 44, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 44 to 44
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# OddWheel was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
#
# Result - Optimal solution found
# Objective value:                44
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.001115
# Time (Wallclock seconds):       0.00129604
# Total time (CPU seconds):       0.001175   (Wallclock seconds):       0.00137401
# Status: OptimizationStatus.OPTIMAL
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0024I Matrix will be packed to eliminate 160 small elements
# Coin0506I Presolve 9 (-15) rows, 9 (0) columns and 30 (-26) elements
# Clp1000I sum of infeasibilities 3.10285e-12 - average 3.44761e-13, 1 fixed columns
# Coin0506I Presolve 9 (0) rows, 8 (-1) columns and 27 (-3) elements
# Clp0006I 0  Obj 44.000007 Dual inf 4800 (8)
# Clp0029I End of values pass after 8 iterations
# Clp0000I Optimal - objective value 44
# Clp0000I Optimal - objective value 44
# Coin0511I After Postsolve, objective 44, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 44
# Clp0000I Optimal - objective value 44
# Clp0000I Optimal - objective value 44
# Clp0000I Optimal - objective value 44
# Coin0511I After Postsolve, objective 44, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 44 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
#
# Starting MIP optimization
# maxSavedSolutions was changed from 1 to 10
# Continuous objective value is 44 - 2.9e-05 seconds
# Cgl0003I 0 fixed, 9 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 9 rows, 9 columns (9 integer (0 of which binary)) and 30 elements
# Coin3009W Conflict graph built in 0.000 seconds, density: 0.000%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0012I Integer solution of 68 found by greedy cover after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0012I Integer solution of 60 found by DiveCoefficient after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0038I Full problem 9 rows 9 columns, reduced to 1 rows 3 columns
# Cbc0012I Integer solution of 48 found by RINS after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0006I The LP relaxation is infeasible or too expensive
# Cbc0013I At root node, 0 cuts changed objective from 44 to 46 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 1 column cuts (1 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (OddWheel) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 8 (ZeroHalf) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 48, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 44 to 46
# Probing was tried 1 times and created 1 cuts of which 0 were active after adding rounds of cuts (1.8e-05 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# OddWheel was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0 seconds)
#
# Result - Optimal solution found
# Objective value:                48
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.001549
# Time (Wallclock seconds):       0.00170612
# Total time (CPU seconds):       0.001606   (Wallclock seconds):       0.00177503
# Status: OptimizationStatus.OPTIMAL

# %% [markdown]
# ### Forecast by day with optimum shift

# %%
forecast_by_day = {
    'date': [],
    'Forecast': []
}
for i, date in enumerate(dates):
    forecast_by_day['date'].append(date)
    forecast_by_day['Forecast'].append(result_shift[i]['W'])

forecast_by_day = pd.DataFrame(forecast_by_day)
forecast_by_day['date'] = forecast_by_day['date'].astype('datetime64[ns]')
forecast_by_day['week'] = forecast_by_day['date'].dt.isocalendar().week
forecast_by_day['day'] = forecast_by_day['date'].dt.isocalendar().day

# %% [markdown]
# ## Parámetros
# __k1 & k2__: (k1 findes libres cada k2 findes)
# __W_real__: cantidad de personas disponibles

# %%
k1= 1
k2 = 2
W_real = 9

max_wf_wk = forecast_by_day.query('day==7 or day==6')['Forecast'].max()
b1 = ceil((k2 * max_wf_wk) / (k2-k1))
D_week=0
for w in forecast_by_day['week'].unique():
    d = forecast_by_day[forecast_by_day['week']==w]['Forecast'].to_list()
    D=0
    for i in d:
        D += i
    if D > D_week:
        D_week = D
b2 = ceil(D/5)
b3 = forecast_by_day['Forecast'].max()

W = max(b1,b2,b3)
print(f"Minimum workforce: {W}")
if W_real > W:
    print("Workforce is enough, surplus: ", W_real-W)
    free_wf_wk = ceil(W_real*k1/k2)
else:
    print("Workforce is not enough, deficit: ", W-W_real)
    free_wf_wk = ceil(W_real*k1/k2)

print(f"Workforce free by Weekend: {free_wf_wk}")
# Out:
# Minimum workforce: 14
# Workforce is not enough, deficit:  5
# Workforce free by Weekend: 5

# %% [markdown]
# ## Obtener superavit diario y agrupar colaborador por Domingo libre

# %%
max_demanda_per_weekend = {w:forecast_by_day[forecast_by_day['week']==w].query('day==7 or day==6')['Forecast'].max() for w in forecast_by_day['week'].unique()}
forecast_by_day['surplus'] = forecast_by_day.apply(lambda row: W_real - row['Forecast'] if row['day'] not in [6, 7] else W_real - max_demanda_per_weekend[row['week']], axis=1)
max_dda_wk = forecast_by_day[(forecast_by_day['day']==7) | (forecast_by_day['day']==6)]['Forecast'].max()

# Caso 1:2
collab_list = [i for i in range(W_real)]
collab_list_wknd = [collab_list[:int(len(collab_list)/2)], collab_list[int(len(collab_list)/2):]]
collab_list_wknd = collab_list_wknd*2

free_wknd_collab = {}
for w, cs in zip(max_demanda_per_weekend, collab_list_wknd):
    free_wknd_collab[w] = cs

# %% [markdown]
# ## Generar Disponibilidad

# %%
def two_highest_keyvalue(dicc):
    dicc_copy = dict(dicc)
    key1 = max(dicc_copy, key=dicc_copy.get)
    del dicc_copy[key1]
    key2 = max(dicc_copy, key=dicc_copy.get)
    return [key1, key2]

# %%
data = []
for c in collab_list:
    for fecha in dates:
        data.append([c, fecha])

df_availability = pd.DataFrame(data, columns=['collaborator', 'date'])
df_availability['availability'] = 1
df_availability['date'] = df_availability['date'].astype('datetime64[ns]')
df_availability['week'] = df_availability['date'].dt.isocalendar().week
df_availability['day'] = df_availability['date'].dt.isocalendar().day

for w in free_wknd_collab: # Dar domingo libres
    for c in free_wknd_collab[w]:
        filtro = (df_availability["collaborator"] == c) & (df_availability["day"] == 7) & (df_availability["week"] == w)
        df_availability.loc[filtro, "availability"] = 0

day_off_by_week = {}
for wk in  free_wknd_collab: # Pares días libres
    surplus_week = forecast_by_day[(forecast_by_day['week']==wk) & (forecast_by_day['day']!=7)][['day','surplus']].set_index('day').to_dict()['surplus']
    day_off_pairs = []
    for j in range(len(collab_list) - len(free_wknd_collab[wk])):
        keys = two_highest_keyvalue(surplus_week)
        surplus_week[keys[0]] -= 1
        surplus_week[keys[1]] -= 1
        day_off_pairs.append(keys)

    day_off_by_week[wk] = day_off_pairs

for wk in day_off_by_week: # Dar libres entre semana
    j = 0
    for c in collab_list:
        if df_availability[(df_availability['collaborator']==c) & (df_availability['week']==wk)]['availability'].sum() == 7:
            days_off = day_off_by_week[wk][j]
            filter1 = (df_availability['collaborator']==c) & (df_availability['week']==wk) & (df_availability['day']==days_off[0])
            filter2 = (df_availability['collaborator']==c) & (df_availability['week']==wk) & (df_availability['day']==days_off[1])
            df_availability.loc[filter1, "availability"] = 0
            df_availability.loc[filter2, "availability"] = 0
            j+=1

# %%
df_availability
# Out:
#      collaborator       date  availability  week  day
# 0               0 2023-09-04             1    36    1
# 1               0 2023-09-05             1    36    2
# 2               0 2023-09-06             1    36    3
# 3               0 2023-09-07             1    36    4
# 4               0 2023-09-08             1    36    5
# ..            ...        ...           ...   ...  ...
# 247             8 2023-09-27             1    39    3
# 248             8 2023-09-28             1    39    4
# 249             8 2023-09-29             1    39    5
# 250             8 2023-09-30             1    39    6
# 251             8 2023-10-01             0    39    7
#
# [252 rows x 5 columns]
